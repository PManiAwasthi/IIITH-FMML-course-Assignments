# %% [markdown]
# <a href="https://colab.research.google.com/github/PManiAwasthi/IIITH-FMML-course-Assignments/blob/main/Module8_lab3_fmml20210268.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-12 14:53:38--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   172MB/s    in 0.4s
#
# 2022-06-12 14:53:39 (172 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22671  1704.00541v2  To ensure interpretability of extracted source...  stat
# 20062   1404.7279v1  Contract bridge occupies nowadays a position o...    cs
# 16702  1705.02452v1  Voice browser applications in Text-to- Speech ...    cs
# 6878   1707.00797v1  We propose a number of new algorithms for lear...  stat
# 25717  1511.03995v3  In surveillance, monitoring and tactical recon...    cs
# ...             ...                                                ...   ...
# 19559   0907.0589v2  Collective graphical models exploit inter-inst...    cs
# 22231  1509.03381v1  Using a proper model to characterize a time se...  stat
# 33545  1612.08813v1  Testing provides means pertaining to assuring ...    cs
# 868    1612.01936v1  We develop a probabilistic framework for deep ...  stat
# 34582  1704.05550v1  Due to its promise to alleviate information ov...    cs
#
#                                                    title  year  \
# 22671  Dictionary-based Tensor Canonical Polyadic Dec...  2017
# 20062  Assessing the players'performance in the game ...  2014
# 16702  A Generative Model of a Pronunciation Lexicon ...  2017
# 6878   Learning Deep Energy Models: Contrastive Diver...  2017
# 25717  LLNet: A Deep Autoencoder Approach to Natural ...  2015
# ...                                                  ...   ...
# 19559  Generalized Collective Inference with Symmetri...  2009
# 22231  Learning the Number of Autoregressive Mixtures...  2015
# 33545  Optimization of Test Case Generation using Gen...  2016
# 868          A Probabilistic Framework for Deep Learning  2016
# 34582  Extractive Summarization: Limits, Compression,...  2017
#
#                                                 keywords
# 22671  [interpretability, extracted, decomposition, i...
# 20062  [officially, recognized, international, commit...
# 16702  [applications, automatic, recognition, crucial...
# 6878   [algorithms, demonstrate, properties, likeliho...
# 25717  [surveillance, monitoring, reconnaissance, gat...
# ...                                                  ...
# 19559  [collective, graphical, associative, dependenc...
# 22231  [characterize, predictions, autoregressive, st...
# 33545  [pertaining, performance, associated, associat...
# 868    [probabilistic, framework, rendering, generati...
# 34582  [alleviate, information, summarization, attrac...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22671    [interpretability, extracted, decomposition, i...
# 20062    [officially, recognized, international, commit...
# 16702    [applications, automatic, recognition, crucial...
# 6878     [algorithms, demonstrate, properties, likeliho...
# 25717    [surveillance, monitoring, reconnaissance, gat...
#                                ...
# 15106    [currently, preparation, evaluation, identifyi...
# 10096    [potential, parameters, formalize, probabilist...
# 12128    [communicationally, computationally, efficient...
# 14160    [metaheuristic, introduced, reasonable, algori...
# 21662    [inference, structure, different, different, i...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8830 words.
# Out of those 4556 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e48ba269-ff68-4cfb-94c7-c822e2272658" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e48ba269-ff68-4cfb-94c7-c822e2272658")) {                    Plotly.newPlot(                        "e48ba269-ff68-4cfb-94c7-c822e2272658",                        [{"x":["formulation","evaluated","interpretability","canonical","dimensional","identifiability","decomposition","hyperspectral","dictionary","parameter","introduce","estimation","performances","algorithms","extracted","simulated","principles","informally","characterizing","tournament","simultaneous","performance","presented","applications","different","linguistic","organized","innovative","collected","complement","represented","statistical","committee","defuzzification","introduced","importance","assessment","recognized","officially","belonging","assessing","illustrating","international","generating","pronunciation","crucially","recognition","generative","placement","automatically","developed","automatic","describes","combining","contrastive","directions","amortized","likelihood","promising","properties","realistic","divergence","traditional","demonstrate","gathering","operation","credibility","brightness","processing","denoising","enhancing","determines","ingredients","decisions","quantitative","essential","enhancement","synthetically","saturation","significant","accurately","monitoring","successfully","reconnaissance","surveillance","adaptively","information","techniques","approaches","environment","handcrafting","comparison","autoencoder","amplifying","naturally","relations","additional","relational","inference","collective","outperforms","empirically","relaxation","connections","comparable","improvements","integrating","iterative","available","procedures","assumption","classification","propagating","extracting","benchmark","consistency","formulate","optimization","selecting","minimization","important","promoting","framework","algorithm","simulations","experiments","factoring","corresponding","complexity","alternating","incorporated","separation","constraints","factorization","regularization","iteration","iteratively","effectiveness","procedure","convergence","suppression","fluorescence","maximally","significance","establish","reliability","parametric","covariance","equivalent","activated","combinations","covariances","components","numerical","explicitly","considering","resulting","expressed","stability","aggregate","correlated","dimensions","reproduced","repetition","eigenvalue","efficiently","deviation","discriminant","correlate","neuroscience","generalized","multivariate","maximization","prediction","parameters","artifacts","deformable","architecture","propagated","therefore","associated","lightweight","identical","probabilistic","difficult","astrophysics","extensive","significantly","sinusoidal","irregularly","analyzing","disciplines","observations","understanding","challenge","nonparametric","estimating","processes","functions","sensitive"],"y":[76,150,22,17,185,2,66,13,46,113,314,196,47,568,121,58,37,3,20,2,34,886,185,441,772,69,18,11,70,21,67,146,7,2,134,96,45,19,2,17,16,5,15,94,6,5,364,106,10,185,198,192,81,104,8,36,3,55,119,214,62,21,166,566,4,35,4,6,296,53,23,22,6,70,82,71,38,6,3,240,71,16,70,2,31,26,688,380,448,131,2,155,33,3,61,84,115,33,199,19,307,71,19,45,90,110,37,66,284,43,69,488,12,50,220,63,59,300,43,71,345,7,544,814,43,627,4,125,239,23,26,24,143,33,98,44,40,200,116,122,6,1,7,17,52,18,39,22,50,3,35,3,101,79,75,77,150,27,40,19,27,48,1,2,9,148,12,18,7,8,69,23,27,215,258,20,14,252,8,143,96,13,14,154,152,4,163,274,1,2,51,9,92,149,145,25,63,109,218,71],"type":"bar"},{"x":["formulation","evaluated","interpretability","canonical","dimensional","identifiability","decomposition", ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4556,), (4556, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8383333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3958333333333333);'>Transformation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Properties</span> <span style=''>of</span> <span style=''>Learned</span> <span style=''>Visual</span> <span style='background-color:rgba(0, 255, 0, 0.340782122905028);'>Representations</span> <br/><br/><span style=''>When</span> <span style=''>a</span> <span style=''>three</span> <span style='background-color:rgba(255, 0, 0, 0.3357271095152604);'>dimensional</span> <span style=''>object</span> <span style=''>moves</span> <span style=''>relative</span> <span style=''>to</span> <span style=''>an</span> <span style=''>observer</span> <span style=''>a</span> <span style=''>change</span> <span style=''>occurs</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>observers</span> <span style=''>image</span> <span style=''>plane</span> <span style=''>and</span> <span style=''>in</span> <span style=''>the</span> <span style=''>visual</span> <span style='background-color:rgba(0, 255, 0, 0.4122137404580152);'>representation</span> <span style=''>computed</span> <span style=''>by</span> <span style=''>a</span> <span style=''>learned</span> <span style=''>model</span> <span style=''>Starting</span> <span style=''>with</span> <span style=''>the</span> <span style=''>idea</span> <span style=''>that</span> <span style=''>a</span> <span style=''>good</span> <span style=''>visual</span> <span style='background-color:rgba(0, 255, 0, 0.4122137404580152);'>representation</span> <span style=''>is</span> <span style=''>one</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transforms</span> <span style=''>linearly</span> <span style=''>under</span> <span style=''>scene</span> <span style=''>motions</span> <span style=''>we</span> <span style=''>show</span> <span style=''>using</span> <span style=''>the</span> <span style=''>theory</span> <span style=''>of</span> <span style=''>group</span> <span style='background-color:rgba(0, 255, 0, 0.340782122905028);'>representations</span> <span style=''>that</span> <span style=''>any</span> <span style=''>such</span> <span style='background-color:rgba(0, 255, 0, 0.4122137404580152);'>representation</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>equivalent</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.37198067632850246);'>combination</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.8823529411764706);'>elementary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>irreducible</span> <span style='background-color:rgba(0, 255, 0, 0.340782122905028);'>representations</span> <span style=''>We</span> <span style=''>derive</span> <span style=''>a</span> <span style=''>striking</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relationship</span> <span style=''>between</span> <span style=''>irreducibility</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.38004246284501064);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependency</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.4122137404580152);'>representation</span> <span style=''>by</span> <span style=''>showing</span> <span style=''>that</span> <span style=''>under</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>restricted</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>irreducible</span> <span style='background-color:rgba(0, 255, 0, 0.340782122905028);'>representations</span> <span style=''>are</span> <span style=''>decorrelated</span> <span style=''>Under</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Principal</span> <span style=''>Geodesic</span> <span style=''>Analysis</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Probability</span> <span style=''>Measures</span> <span style=''>under</span> <span style=''>the</span> <span style=''>Optimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Transport</span> <span style=''>Metric</span> <br/><br/><span style=''>Given</span> <span style=''>a</span> <span style=''>family</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>measures</span> <span style=''>in</span> <span style=''>P(X)</span> <span style=''>the</span> <span style=''>space</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>measures</span> <span style=''>on</span> <span style=''>a</span> <span style=''>Hilbert</span> <span style=''>space</span> <span style=''>X</span> <span style=''>our</span> <span style=''>goal</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>is</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>highlight</span> <span style=''>one</span> <span style=''>ore</span> <span style=''>more</span> <span style=''>curves</span> <span style=''>in</span> <span style=''>P(X)</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>summarize</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiently</span> <span style=''>that</span> <span style=''>family</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>study</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>under</span> <span style=''>the</span> <span style=''>optimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transport</span> <span style=''>(Wasserstein)</span> <span style=''>geometry</span> <span style=''>using</span> <span style=''>curves</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>restricted</span> <span style=''>to</span> <span style=''>be</span> <span style=''>geodesic</span> <span style=''>segments</span> <span style=''>under</span> <span style=''>that</span> <span style=''>metric</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>concepts</span> <span style=''>that</span> <span style=''>play</span> <span style=''>a</span> <span style=''>key</span> <span style=''>role</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Euclidean</span> <span style=''>PCA</span> <span style=''>such</span> <span style=''>as</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>centering</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>orthogonality</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>directions</span> <span style=''>find</span> <span style=''>a</span> <span style=''>natural</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equivalent</span> <span style=''>in</span> <span style=''>the</span> <span style=''>optimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transport</span> <span style=''>geometry</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Wasserstein</span> <span style=''>means</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>differential</span> <span style=''>geometry</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implementation</span> <span style=''>of</span> <span style=''>these</span> <span style=''>ideas</span> <span style=''>is</sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.4666666666666667);'>Contextual</span> <span style=''>Multi</span> <span style=''>armed</span> <span style=''>Bandits</span> <span style=''>under</span> <span style=''>Feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Uncertainty</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style='background-color:rgba(0, 255, 0, 0.4666666666666667);'>contextual</span> <span style=''>multi</span> <span style=''>armed</span> <span style=''>bandit</span> <span style=''>problems</span> <span style=''>under</span> <span style=''>linear</span> <span style=''>realizability</span> <span style=''>on</span> <span style=''>rewards</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>uncertainty</span> <span style=''>(or</span> <span style=''>noise)</span> <span style=''>on</span> <span style=''>features</span> <span style=''>For</span> <span style=''>the</span> <span style=''>case</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identical</span> <span style=''>noise</span> <span style=''>on</span> <span style=''>features</span> <span style=''>across</span> <span style=''>actions</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>coined</span> <span style=''>em</span> <span style=''>NLinRel</span> <span style=''>having</span> <span style=''>Oleft(Tfrac78</span> <span style=''>left(log(dT)Ksqrtdright)right)</span> <span style=''>regret</span> <span style=''>bound</span> <span style=''>for</span> <span style=''>T</span> <span style=''>rounds</span> <span style=''>K</span> <span style=''>actions</span> <span style=''>and</span> <span style=''>d</span> <span style='background-color:rgba(255, 0, 0, 0.3357271095152604);'>dimensional</span> <span style=''>feature</span> <span style=''>vectors</span> <span style=''>Next</span> <span style=''>for</span> <span style=''>the</span> <span style=''>case</span> <span style=''>of</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identical</span> <span style=''>noise</span> <span style=''>we</span> <span style=''>observe</span> <span style=''>that</span> <span style=''>popular</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.4545454545454546);'>hypotheses</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style=''>em</span> <span style=''>NLinRel</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>impossible</span> <span style=''>to</span> <span style=''>achieve</span> <span style=''>such</span> <span style=''>sub</span> <span style=''>linear</span> <span style=''>regret</span> <span style=''>Instead</span> <span style=''>under</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assumption</span> <span style=''>of</span> <span style=''>Gaussian</span> <span style=''>feature</span> <span style=''>vectors</span> <span style=''>we</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>a</span> <span style=''>greedy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>has</span> <span style=''>Oleft(Tfrac23sqrtlog</span> <span style=''>dright)</span> <span style=''>regret</span> <span style=''>bound</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>to</span> <span style=''>the</span> <span style=''>optimal</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesis</span> <span style='background-color:rgba(0, 255, 0, 0.35211267605633806);'>Utilizing</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.32568807339449546);'>theoretical</span> <span style='background-color:rgba(0, 255, 0, 0.31277533039647576);'>understanding</span> <span style=''>on< ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Towards</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Mathematical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Foundation</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Immunology</span> <span style=''>and</span> <span style=''>Amino</span> <span style=''>Acid</span> <span style=''>Chains</span> <br/><br/><span style=''>We</span> <span style=''>attempt</span> <span style=''>to</span> <span style=''>set</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>mathematical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>foundation</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>immunology</span> <span style=''>and</span> <span style=''>amino</span> <span style=''>acid</span> <span style=''>chains</span> <span style=''>To</span> <span style=''>measure</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarities</span> <span style=''>of</span> <span style=''>these</span> <span style=''>chains</span> <span style=''>a</span> <span style=''>kernel</span> <span style=''>on</span> <span style=''>strings</span> <span style=''>is</span> <span style=''>defined</span> <span style=''>using</span> <span style=''>only</span> <span style=''>the</span> <span style=''>sequence</span> <span style=''>of</span> <span style=''>the</span> <span style=''>chains</span> <span style=''>and</span> <span style=''>a</span> <span style=''>good</span> <span style=''>amino</span> <span style=''>acid</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>substitution</span> <span style=''>matrix</span> <span style=''>(eg</span> <span style=''>BLOSUM62)</span> <span style=''>The</span> <span style=''>kernel</span> <span style=''>is</span> <span style=''>used</span> <span style=''>in</span> <span style=''>learning</span> <span style=''>machines</span> <span style=''>to</span> <span style=''>predict</span> <span style=''>binding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>affinities</span> <span style=''>of</span> <span style=''>peptides</span> <span style=''>to</span> <span style=''>human</span> <span style=''>leukocyte</span> <span style=''>antigens</span> <span style=''>DR</span> <span style=''>(HLA</span> <span style=''>DR)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>molecules</span> <span style=''>On</span> <span style=''>both</span> <span style=''>fixed</span> <span style=''>allele</span> <span style=''>(Nielsen</span> <span style=''>and</span> <span style=''>Lund</span> <span style=''>2009)</span> <span style=''>and</span> <span style=''>pan</span> <span style=''>allele</span> <span style=''>(Nielsen</span> <span style=''>etal</span> <span style=''>2010)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>benchmark</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>databases</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>achieves</span> <span style=''>the</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>The</span> <span style=''>kernel</span> <span style=''>is</span> <span style=''>also</span> <span style=''>used</span> <span style=''>to</span> <span style=''>define</span> <span style=''>a</span> <span style=''>distance</span> <span style=''>on</span> <span style=''>an</span> <span style=''>HLA</span> <span style=''>DR</span> <span style=''>allele</span> <span style=''>set</span> <span style=''>based</span> <span style=''>on</span> <span style=''>which</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>analysis</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>precisely</span> <span style=''>reco ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12687099073414113)
# 	processing (0.10548823948681398)
# 	segmentation (0.07127583749109052)
# 	representation (0.13186029935851745)
# 	information (0.2451888809693514)
# 	architecture (0.08980755523877405)
# 	detection (0.13043478260869565)
# 	recognition (0.12972202423378476)
# 	different (0.2751247327156094)
# 	convolutional (0.14397719173200285)
#
# Some Statistics words are:
# 	algorithms (0.2858575727181545)
# 	theoretical (0.14493480441323972)
# 	algorithm (0.3946840521564694)
# 	estimation (0.17552657973921765)
# 	variables (0.1489468405215647)
# 	distribution (0.18355065195586762)
# 	statistical (0.1629889669007021)
# 	dimensional (0.18655967903711135)
# 	inference (0.1945837512537613)
# 	regression (0.18906720160481444)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0bfd423e-b6ce-45db-83d1-c0ebc762f3a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0bfd423e-b6ce-45db-83d1-c0ebc762f3a9")) {                    Plotly.newPlot(                        "0bfd423e-b6ce-45db-83d1-c0ebc762f3a9",                        [{"x":["formulation","evaluated","interpretability","canonical","dimensional","identifiability","decomposition","hyperspectral","dictionary","parameter","introduce","estimation","performances","algorithms","extracted","simulated","principles","informally","characterizing","tournament","simultaneous","performance","presented","applications","different","linguistic","organized","innovative","collected","complement","represented","statistical","committee","defuzzification","introduced","importance","assessment","recognized","officially","belonging","assessing","illustrating","international","generating","pronunciation","crucially","recognition","generative","placement","automatically","developed","automatic","describes","combining","contrastive","directions","amortized","likelihood","promising","properties","realistic","divergence","traditional","demonstrate","gathering","operation","credibility","brightness","processing","denoising","enhancing","determines","ingredients","decisions","quantitative","essential","enhancement","synthetically","saturation","significant","accurately","monitoring","successfully","reconnaissance","surveillance","adaptively","information","techniques","approaches","environment","handcrafting","comparison","autoencoder","amplifying","naturally","relations","additional","relational","inference","collective","outperforms","empirically","relaxation","connections","comparable","improvements","integrating","iterative","available","procedures","assumption","classification","propagating","extracting","benchmark","consistency","formulate","optimization","selecting","minimization","important","promoting","framework","algorithm","simulations","experiments","factoring","corresponding","complexity","alternating","incorporated","separation","constraints","factorization","regularization","iteration","iteratively","effectiveness","procedure","convergence","suppression","fluorescence","maximally","significance","establish","reliability","parametric","covariance","equivalent","activated","combinations","covariances","components","numerical","explicitly","considering","resulting","expressed","stability","aggregate","correlated","dimensions","reproduced","repetition","eigenvalue","efficiently","deviation","discriminant","correlate","neuroscience","generalized","multivariate","maximization","prediction","parameters","artifacts","deformable","architecture","propagated","therefore","associated","lightweight","identical","probabilistic","difficult","astrophysics","extensive","significantly","sinusoidal","irregularly","analyzing","disciplines","observations","understanding","challenge","nonparametric","estimating","processes","functions","sensitive","knowledge","improvement","assumptions","identifying","experimental","mechanisms","incorporate","contributions","incorporates","posterior","mismatched","sketching","characterize","precision","measurements","particular","efficient","eigenvectors","sequential","decreasing","initialization","eigenvalues","artificial","achieving","distributed","emergence","movements","formations","indicators","stabilization","independent","positioning","cognitive","reasoning","implemented","selection","development","visualization","counterparts","practical","highlight","summarizing","attention","mechanistic","reasonable","psychoanalysis","abilities","perception","established","architectures","remaining","engineering","prominently","technology","locations","substantiall ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	sketching
# 	prominently
# 	abstention
# 	continual
# 	spectroradiometer
# 	incidentally
# 	interventional
# 	nonparametrically
# 	substantive
# 	elliptical
# 	signaling
# 	epidemics
# 	appliances
# 	definiteness
# 	modulating
# 	discretised
# 	psychiatric
# 	assimilation
# 	hydrology
# 	variationally
# Some words which never appear in Statistics papers:
# 	defuzzification
# 	officially
# 	pronunciation
# 	credibility
# 	reconnaissance
# 	handcrafting
# 	amplifying
# 	deformable
# 	formations
# 	stabilization
# 	psychoanalysis
# 	repetitively
# 	smartphone
# 	instruction
# 	executions
# 	accompany
# 	activitynet
# 	chromatic
# 	atmosphere
# 	reservoir

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0659798871719406e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.79
